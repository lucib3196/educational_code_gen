# %%
import pandas as pd
csv_path = r"C:\Users\lberm\OneDrive\Desktop\GitHub_Repository\educational_code_gen\Question_Embedding_20240128.csv"
pd.read_csv(csv_path)
# Out:
#                                    Question Title  Unnamed: 0  \
# 0                                       3dMoment1         0.0
# 1                                       3dMoment2         1.0
# 2                                       3dMoment3         2.0
# 3                                       3dMoment4         3.0
# 4                                    Equilibrium1         4.0
# ..                                            ...         ...
# 258     preclass_2.1.6_Truck Acceleration Problem         NaN
# 259            preclass_2.1.7_Vertical Ball Throw         NaN
# 260           preclass_2.1.8_Cannon Ball Velocity         NaN
# 261  preclass_2.1.9_Maximum Height of Cannon Ball         NaN
# 262             preclass_2.1_1_Sky Diving Physics         NaN
#
#                                              info.json  \
# 0    {\n    "uuid": "8abcd91d6-64d1-4e89-b72d-ad213...
# 1    {\n    "uuid": "8abcd91d6-64d1-4e89-b72d-ad213...
# 2    {\n    "uuid": "8abcd91d6-64d1-4e89-b72d-ad213...
# 3    {\n    "uuid": "8abcd91d6-64d1-4e89-b72d-ad213...
# 4    {\n    "uuid": "8abcd91d6-64d1-4e89-b72d-ad213...
# ..                                                 ...
# 258  {"uuid": "d7f7a3e6-8b3d-4e3b-9c3a-6f3d7a8b3d4e...
# 259  {\n    "uuid": "d6f8b8a7-3c3e-4e3d-9b3a-6f3c4d...
# 260  {"uuid": "a1b2c3d4-e5f6-g7h8-i9j0-k1l2m3n4o5p"...
# 261  {"uuid": "a1b2c3d4-e5f6-g7h8-i9j0-k1l2m3n4o5p"...
# 262  {"uuid": "a1b9c8d7-e6f5-g4h3-i2j1k0l9m8n7", "t...
#
#                                          question.html  \
# 0    <pl-question-panel>\n    <pl-figure file-name=...
# 1    <pl-question-panel>\n    <pl-figure file-name=...
# 2    <pl-question-panel>\n    <pl-figure file-name=...
# 3    <pl-question-panel>\n    <pl-figure file-name=...
# 4    <pl-question-panel>\n<pl-figure file-name="3dP...
# ..                                                 ...
# 258  <pl-question-panel>\n  <p> A truck traveling a...
# 259  <pl-question-panel>\n  <p> A ball is thrown ve...
# 260  <pl-question-panel>\n  <p> A cannon fires a ca...
# 261  <pl-question-panel>\n  <p> A cannon fires a ca...
# 262  <pl-question-panel> \n  <p>\n    A sky diver j...
#
#                                              server.js  \
# 0    const math = require('mathjs');\n// const math...
# 1    const math = require('mathjs');\n// const math...
# 2    const math = require('mathjs');\n// const math...
# 3    const math = require('mathjs');\n// const math...
# 4    const math = require('mathjs');\n// const math...
# ..                                                 ...
# 258  const math = require('mathjs');\n\n\n\n/**\n *...
# 259  const math = require('mathjs');\n\nconst gener...
# 260  const math = require('mathjs');\n\nconst gener...
# 261  const math = require('mathjs');\n\nconst gener...
# 262                                                NaN
#
#                                          solution.html server.py  \
# 0    <pl-solution-panel>\n    <pl-figure file-name=...       NaN
# 1    <pl-solution-panel>\n    <pl-figure file-name=...       NaN
# 2    <pl-solution-panel>\n    <pl-figure file-name=...       NaN
# 3    <pl-solution-panel>\n    <pl-figure file-name=...       NaN
# 4    <pl-solution-panel>\n    <pl-figure file-name=...       NaN
# ..                                                 ...       ...
# 258  <pl-solution-panel>\n    <pl-hint level="1" da...       NaN
# 259  <pl-solution-panel>\n    <pl-hint level="1" da...       NaN
# 260  <pl-solution-panel>\n    <pl-hint level="1" da...       NaN
# 261  <pl-solution-panel>\n    <pl-hint level="1" da...       NaN
# 262                                                NaN       NaN
#
#     properties.js info1.json server_trap.js server1.py server2.py test1.py  \
# 0             NaN        NaN            NaN        NaN        NaN      NaN
# 1             NaN        NaN            NaN        NaN        NaN      NaN
# 2             NaN        NaN            NaN        NaN        NaN      NaN
# 3             NaN        NaN            NaN        NaN        NaN      NaN
# 4             NaN        NaN            NaN        NaN        NaN      NaN
# ..            ...        ...            ...        ...        ...      ...
# 258           NaN        NaN            NaN        NaN        NaN      NaN
# 259           NaN        NaN            NaN        NaN        NaN      NaN
# 260           NaN        NaN            NaN        NaN        NaN      NaN
# 261           NaN        NaN            NaN        NaN        NaN      NaN
# 262           NaN        NaN            NaN        NaN        NaN      NaN
#
#     server3.py  .DS_Store                                           question  \
# 0          NaN        NaN  determine the moment about point o in ($n \cdo...
# 1          NaN        NaN  Refer to the diagram labeled "3dMoment2.png". ...
# 2          NaN        NaN  determine the resultant moment produced by the...
# 3          NaN        NaN  determine the resultant moments produced by th...
# 4          NaN        NaN  compute the missing force vector that will all...
# ..         ...        ...                                                ...
# 258        NaN        NaN  a truck traveling at {{params.v}} {{params.uni...
# 259        NaN        NaN  input: consider a ball thrown vertically upwar...
# 260        NaN        NaN  a cannon fires a cannon ball at an angle of 45...
# 261        NaN        NaN  a cannon fires a cannon ball at an angle {{par...
# 262        NaN        NaN  A sky diver jumps out of a plane. Which of the...
#
#                                     question_embedding
# 0    [-0.014649350196123123, -0.019685911014676094,...
# 1    [-0.01250634528696537, 0.0026884342078119516, ...
# 2    [-0.02083856426179409, -0.010903744958341122, ...
# 3    [-0.026474930346012115, -0.008942083455622196,...
# 4    [-0.006892481818795204, -0.0054155210964381695...
# ..                                                 ...
# 258  [-0.01792447827756405, 0.010508396662771702, 0...
# 259  [0.003132258076220751, 0.013810810633003712, -...
# 260  [-0.022996792569756508, 0.019982967525720596, ...
# 261  [-0.010933673940598965, 0.006121629849076271, ...
# 262  [-0.0019656652584671974, 0.00293960003182292, ...
#
# [263 rows x 17 columns]

# %%
from util_semantic_search import SemanticSearch

api_key = "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"  # Replace with your actual API key                
# Configuration variables
data_csv_path = "Question_Embedding_20240128.csv"
embedding_model_name = "text-embedding-ada-002"
search_column = "question"  # Column name in the CSV
number_of_examples = 3


input_questions = [
    "A 70-0 mph braking distance for a car is 170 feet. What's the deceleration in ft/s^2 ?",
    "A force of 50 Kn is applied to a cross-sectional area of 5mm what is the pressure in MPA?"
]
    


# Initialize the SemanticSearch instance
semantic_search_instance = SemanticSearch(data_csv_path, "question_embedding", embedding_model_name,api_key=api_key)

for question in input_questions:

    # Extract examples using SemanticSearch
    extracted_examples = semantic_search_instance.extract_examples(
        input_string=question,
        search_column=search_column,
        output_column="question.html",
        n_examples=number_of_examples
    )


    # Pretty print extracted examples (uncomment if needed)
    semantic_search_instance.pretty_print_extracted_examples(
        question,
        search_column=search_column,
        output_column="question.html",
        n_examples=number_of_examples
    )
    
    # Pretty print semantic search results (uncomment if needed)
    semantic_search_instance.pretty_print_semantic_results(
        question,
        search_column,
        number_of_examples
    )
# Out:
# Extracted Examples for: 'A 70-0 mph braking distance for a car is 170 feet. What's the deceleration in ft/s^2 ?'
#
# Input Example                                               Output Example
# ------------------------------------------------------------------------------------------------------------------------
# a 70-0 mph braking distance for a car is 50 meters.
#
# wha...<pl-question-panel>
#   <p> A 70-0 mph braking distance for...
# a 60 km/h - 0 km/h braking distance for a car is 20 meter...<pl-question-panel>
#   <p> A {{params.v1}} {{params.unitsS...
# a 20 m/s - 10 m/s braking distance for a car is 50 meters...<pl-question-panel>
#   <p> A {{params.v1}} {{params.unitsS...
#
#
# Semantic Search Results for: 'A 70-0 mph braking distance for a car is 170 feet. What's the deceleration in ft/s^2 ?'
#
# Index     Similarity Score    Semantic Example
# ------------------------------------------------------------------------------------------
# 246       0.94                a 70-0 mph braking distance for a car is 50 meters.
#
# what's the deceleration in meters per second s...
# 248       0.86                a 60 km/h - 0 km/h braking distance for a car is 20 meters. how far (in meters) will the car travel ...
# 247       0.84                a 20 m/s - 10 m/s braking distance for a car is 50 meters.
# how long (in seconds) does it take for th...
#
#
# Extracted Examples for: 'A force of 50 Kn is applied to a cross-sectional area of 5mm what is the pressure in MPA?'
#
# Input Example                                               Output Example
# ------------------------------------------------------------------------------------------------------------------------
# a force of magnitude 50 n has its origin at (2, 3, 4) met...<pl-question-panel>
# A force of magnitude {{params.Fmag}} ...
# a force of magnitude 50 n has its origin at (2, 3) m and ...<pl-question-panel>
# A force of magnitude {{params.Fmag}} ...
# two prismatic bars are fastened together and support a lo...<pl-question-panel>
#
#     <p> Two prismatic bars are f...
#
#
# Semantic Search Results for: 'A force of 50 Kn is applied to a cross-sectional area of 5mm what is the pressure in MPA?'
#
# Index     Similarity Score    Semantic Example
# ------------------------------------------------------------------------------------------
# 141       0.83                a force of magnitude 50 n has its origin at (2, 3, 4) meters and ends at (5, 6, 7) meters.
#
# what ar...
# 140       0.83                a force of magnitude 50 n has its origin at (2, 3) m and ends at (5, 7) m.
#
# what are the components...
# 219       0.82                two prismatic bars are fastened together and support a load in the vertical direction with magnitude...

# %%
# Out:
# Semantic Search Results for: 'A 70-0 mph braking distance for a car is 170 feet. What's the deceleration in ft/s^2 ?'
#
# Index     Similarity Score    Semantic Example
# ------------------------------------------------------------------------------------------
# 246       0.94                a 70-0 mph braking distance for a car is 50 meters.
#
# what's the deceleration in meters per second s...
# 248       0.86                a 60 km/h - 0 km/h braking distance for a car is 20 meters. how far (in meters) will the car travel ...
# 247       0.84                a 20 m/s - 10 m/s braking distance for a car is 50 meters.
# how long (in seconds) does it take for th...
